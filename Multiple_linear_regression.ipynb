# %%
import pandas as pd
dataset=pd.read_csv(r"Salary_Data.csv")
dataset.head(5)
# Out:
#     Age  YearsExperience  Salary
# 0  21.0              1.1   39343
# 1  21.5              1.3   46205
# 2  21.7              1.5   37731
# 3  22.0              2.0   43525
# 4  22.2              2.2   39891

# %% [markdown]
# Check the Null value

# %%
dataset.isnull().sum()
# Out:
# Age                0
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# Check graph Follow linearity
# It has two method

# %%
# First method of pairplt
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(dataset)

# %%
# Second method using subplot
plt.figure(figsize=(14,5))
x1=dataset["YearsExperience"]
y=dataset["Salary"]
plt.subplot(1,2,1)
plt.scatter(x1,y,c="blue")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.subplot(1,2,2)
x2=dataset["Age"]
plt.scatter(x2,y,c="red")
plt.ylabel("Salary")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x=dataset[["Age","YearsExperience"]]
y=dataset["Salary"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x,y)
model.score(x_test,y_test)
# Out:
# 0.902003738998495

# %%
# Equartion according to this data
# y=m1x1+m2x2+c
model.coef_
# Out:
# array([1836.01359426, 6153.35330145])

# %%
# Here     m1                 m2
# [1836.01359426, 6153.35330145]
model.intercept_
# Out:
# np.float64(-6661.987198813105)

# %%
x.columns
# Out:
# Index(['Age', 'YearsExperience'], dtype='object')

# %%
# y=m1x1+m2x2+c
# y_predict=1836.01359426*Age ka first element + 6153.35330145*Age ka second element + (-6661.987198813105)
y_predict=model.predict([[21,1.1]])
y_predict
# Out:
# C:\Users\Abubakar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([38662.98691225])
